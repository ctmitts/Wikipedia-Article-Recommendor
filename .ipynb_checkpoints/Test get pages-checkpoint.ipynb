# %%
import request_category as rc

# %%
import pandas as pd
import numpy as np

import datetime

# %%
cat_dict = rc.get_pages( 'machine learning', depth = 3)

# %% [markdown]
# ## Verify Category Dictionary

# %%
print( cat_dict.keys())
print( len(cat_dict.keys()))
# Out:
# dict_keys(['machine learning', 'Applied machine learning', 'Artificial neural networks', 'Deep learning', 'Neural network software', 'Bayesian networks', 'Classification algorithms', 'Decision trees', 'Ensemble learning', 'Cluster analysis', 'Cluster analysis algorithms', 'Clustering criteria', 'Computational learning theory', 'Artificial intelligence conferences', 'Data mining and machine learning software', 'Social network analysis software', 'Datasets in machine learning', 'Datasets in computer vision', 'Dimension reduction', 'Factor analysis', 'Evolutionary algorithms', 'Gene expression programming', 'Genetic algorithms', 'Artificial immune systems', 'Genetic programming', 'Nature-inspired metaheuristics', 'Inductive logic programming', 'Kernel methods for machine learning', 'Support vector machines', 'Latent variable models', 'Structural equation models', 'Learning in computer vision', 'Log-linear models', 'Loss functions', 'Machine learning algorithms', 'Machine learning task', 'Markov models', 'Hidden Markov models', 'Markov networks', 'Machine learning researchers', 'Semisupervised learning', 'Statistical natural language processing', 'Language modeling', 'Structured prediction', 'Graphical models', 'Causal inference', 'Supervised learning', 'Unsupervised learning'])
# 48

# %%
orig_cats = cat_dict['machine learning'].subcategory.unique().tolist()
len( cat_dict['machine learning'].subcategory.unique().tolist())
# Out:
# 48

# %%
cat_dict['machine learning'].shape
# Out:
# (1311, 5)

# %%
print( 'Total Articles: {}'. format( cat_dict['machine learning'].subcategory.value_counts().sum()) )
print( '_'*100)
print( cat_dict['machine learning'].subcategory.value_counts() )
# Out:
# Total Articles: 1311
# ____________________________________________________________________________________________________
# machine learning                             197
# Artificial neural networks                   129
# Data mining and machine learning software     87
# Machine learning researchers                  82
# Classification algorithms                     81
# Machine learning algorithms                   57
# Markov models                                 52
# Genetic algorithms                            41
# Evolutionary algorithms                       40
# Dimension reduction                           39
# Cluster analysis algorithms                   38
# Statistical natural language processing       35
# Applied machine learning                      35
# Latent variable models                        25
# Causal inference                              24
# Neural network software                       22
# Computational learning theory                 21
# Deep learning                                 20
# Graphical models                              20
# Factor analysis                               19
# Nature-inspired metaheuristics                18
# Cluster analysis                              18
# Decision trees                                17
# Clustering criteria                           16
# Kernel methods for machine learning           15
# Ensemble learning                             14
# Artificial intelligence conferences           14
# Genetic programming                           12
# Bayesian networks                             12
# Unsupervised learning                         11
# Language modeling                             11
# Datasets in computer vision                   10
# Structural equation models                     9
# Loss functions                                 8
# Hidden Markov models                           8
# Support vector machines                        8
# Markov networks                                7
# Datasets in machine learning                   6
# Social network analysis software               6
# Inductive logic programming                    5
# Machine learning task                          5
# Structured prediction                          4
# Learning in computer vision                    4
# Artificial immune systems                      4
# Log-linear models                              2
# Gene expression programming                    1
# Semisupervised learning                        1
# Supervised learning                            1
# Name: subcategory, dtype: int64

# %%
cat_dict['Artificial neural networks'].shape
# Out:
# (171, 5)

# %%
print( 'Total Articles: {}'. format( cat_dict['Artificial neural networks'].subcategory.value_counts().sum()) )
print( '_'*100)
print( cat_dict['Artificial neural networks'].subcategory.value_counts())
# Out:
# Total Articles: 171
# ____________________________________________________________________________________________________
# Artificial neural networks    129
# Neural network software        22
# Deep learning                  20
# Name: subcategory, dtype: int64

# %%
cat_dict['Deep learning'].subcategory.value_counts()
# Out:
# Deep learning    20
# Name: subcategory, dtype: int64

# %%
cat_dict['Neural network software'].subcategory.value_counts()
# Out:
# Neural network software    22
# Name: subcategory, dtype: int64

# %% [markdown]
# ## Lets transform the dictionary of categories into a DataFrame

# %%
n_categories = len( cat_dict.keys()) 
n_categories
# Out:
# 48

# %%
category_pages_df = pd.concat( cat_dict.values())
category_pages_df.shape
# Out:
# (3053, 5)

# %%
category_pages_df.head(15)

# %% [markdown]
# ## Display Hierchical Structure of Category

# %%
print( 'Total titles: {}'.format(category_pages_df.drop( ['ns', 'pageid'], axis = 1).groupby( by = ['category', 'subcategory']).count().sum() ) )
category_pages_df.drop( ['ns', 'pageid'], axis = 1).groupby( by = ['category', 'subcategory']).count()
# Out:
# Total titles: title    3053
# dtype: int64
#                                                                                      title
# category                                  subcategory
# Applied machine learning                  Applied machine learning                      35
# Artificial immune systems                 Artificial immune systems                      4
# Artificial intelligence conferences       Artificial intelligence conferences           14
# Artificial neural networks                Artificial neural networks                   129
#                                           Deep learning                                 20
#                                           Neural network software                       22
# Bayesian networks                         Bayesian networks                             12
# Causal inference                          Causal inference                              24
# Classification algorithms                 Artificial neural networks                   129
#                                           Classification algorithms                     81
#                                           Decision trees                                17
#                                           Deep learning                                 20
#                                           Ensemble learning                             14
#                                           Neural network software                       22
# Cluster analysis                          Cluster analysis                              18
#                                           Cluster analysis algorithms                   38
#                                           Clustering criteria                           16
# Cluster analysis algorithms               Cluster analysis algorithms                   38
# Clustering criteria                       Clustering criteria                           16
# Computational learning theory             Computational learning theory                 21
# Data mining and machine learning software Data mining and machine learning software     87
#                                           Social network analysis software               6
# Datasets in computer vision               Datasets in computer vision                   10
# Datasets in machine learning              Datasets in computer vision                   10
#                                           Datasets in machine learning                   6
# Decision trees                            Decision trees                                17
# Deep learning                             Deep learning                                 20
# Dimension reduction                       Dimension reduction                           39
#                                           Factor analysis                               19
# Ensemble learning                         Ensemble learning                             14
# ...                                                                                    ...
# machine learning                          Evolutionary algorithms                       40
#                                           Factor analysis                               19
#                                           Gene expression programming                    1
#                                           Genetic algorithms                            41
#                                           Genetic programming                           12
#                                           Graphical models                              20
#                                           Hidden Markov models                           8
#                                           Inductive logic programming                    5
#                                           Kernel methods for machine learning           15
#                                           Language modeling                             11
#                                           Latent variable models                        25
#                                           Learning in computer vision                    4
#                                           Log-linear models                              2
#                                           Loss functions                                 8
#                                           Machine learning algorithms                   57
#                                           Machine learning researchers                  82
#                                           Machine learning task                          5
#                                           Markov models                                 52
#                                           Markov networks                                7
#                                           Nature-inspired metaheuristics                18
#                                           Neural network software                       22
#                                           Semisupervised learning                        1
#                                           Social network analysis software               6
#                                           Statistical natural language processing       35
#                                           Structural equation models                     9
#                                           Structured prediction                          4
#                                           Supervised learning                            1
#                                           Support vector machines                        8
#                                           Unsupervised learning                         11
#                                           machine learning                             197
#
# [130 rows x 1 columns]

# %%
import requests
import psycopg2 as pg2
from psycopg2.extras import RealDictCursor
import wikipedia
from spacy.en import STOP_WORDS
from spacy.en import English
from datetime import datetime

nlp = English()
time_of_one_grab = .661189

# %%
def fill_unique_pages( category, depth = 3, grab = False):
    start = datetime.now()
    print('Gathering page information from Category: {}, pages from nested sub-categories (+{} levels) will be included as a union for each category. '.format( category, depth))
    category_dict = rc.get_pages( category, depth)  ## REMOVE rc if copying into script
    n_categories = len( category_dict.keys()) 
    print('\tTotal categories after recursive search: {}'.format( n_categories) )
    
    try:
        category_pages_df = pd.concat( category_dict.values())
    
        category_pages_df.drop('ns', axis = 1, inplace = True)
        category_pages_df.reset_index( drop = True, inplace = True)
        
        unique_pages_df = category_pages_df.drop_duplicates(subset = ['pageid', 'title']).copy() ## Drop members with the same pageid & title
        unique_pages_df.reset_index( drop = True, inplace = True)
        
        n_grabs = unique_pages_df.shape[0]
        #print( unique_pages_df.shape, n_grabs)
        
        estT = round(time_of_one_grab*n_grabs/60, 2)  ## minutes
        print('\tRequesting {} unique articles - ETA: {} minutes'.format( n_grabs, estT))
        if grab:
            unique_pages_df['article'] = unique_pages_df.pageid.apply( grab_content )  ## Grab content and clean it
            tag = ''
        else:
            tag = '(article excluded)'
        totT = round((datetime.now()-start).seconds/60,2) ## minutes
        print('\t\tPage collection {} took a total of {} minutes'.format(tag, totT) )
        return category_pages_df, unique_pages_df
    
    except:
        print( 'Nothing to fill.')

# %%
ml_category_pages_df, ml_unique_pages_df = fill_unique_pages( 'machine learning', depth = 3, grab = False)
# Out:
# Gathering page information from Category: machine learning, pages from nested sub-categories (+3 levels) will be included as a union for each category.
# 	Total categories after recursive search: 48
# 	Requesting 1096 unique articles - ETA: 12.08 minutes
# 		Page collection (article excluded) took a total of 0.27 minutes

# %%
ml_category_pages_df.shape
# Out:
# (3055, 4)

# %%
ml_category_pages_df.head()
# Out:
#            category    pageid       subcategory  \
# 0  machine learning  43385931  machine learning
# 1  machine learning  49082762  machine learning
# 2  machine learning    233488  machine learning
# 3  machine learning  53587467  machine learning
# 4  machine learning   3771060  machine learning
#
#                                             title
# 0                                Data exploration
# 1  List of datasets for machine learning research
# 2                                Machine learning
# 3                     Outline of machine learning
# 4                                Accuracy paradox

# %%
print( 'Total titles: {}'.format(ml_category_pages_df.drop( ['pageid'], axis = 1).groupby( by = ['category', 'subcategory']).count().sum() ) )
ml_category_pages_df.drop( ['pageid'], axis = 1).groupby( by = ['category', 'subcategory']).count()
# Out:
# Total titles: title    3053
# dtype: int64
#                                                                                      title
# category                                  subcategory
# Applied machine learning                  Applied machine learning                      35
# Artificial immune systems                 Artificial immune systems                      4
# Artificial intelligence conferences       Artificial intelligence conferences           14
# Artificial neural networks                Artificial neural networks                   129
#                                           Deep learning                                 20
#                                           Neural network software                       22
# Bayesian networks                         Bayesian networks                             12
# Causal inference                          Causal inference                              24
# Classification algorithms                 Artificial neural networks                   129
#                                           Classification algorithms                     81
#                                           Decision trees                                17
#                                           Deep learning                                 20
#                                           Ensemble learning                             14
#                                           Neural network software                       22
# Cluster analysis                          Cluster analysis                              18
#                                           Cluster analysis algorithms                   38
#                                           Clustering criteria                           16
# Cluster analysis algorithms               Cluster analysis algorithms                   38
# Clustering criteria                       Clustering criteria                           16
# Computational learning theory             Computational learning theory                 21
# Data mining and machine learning software Data mining and machine learning software     87
#                                           Social network analysis software               6
# Datasets in computer vision               Datasets in computer vision                   10
# Datasets in machine learning              Datasets in computer vision                   10
#                                           Datasets in machine learning                   6
# Decision trees                            Decision trees                                17
# Deep learning                             Deep learning                                 20
# Dimension reduction                       Dimension reduction                           39
#                                           Factor analysis                               19
# Ensemble learning                         Ensemble learning                             14
# ...                                                                                    ...
# machine learning                          Evolutionary algorithms                       40
#                                           Factor analysis                               19
#                                           Gene expression programming                    1
#                                           Genetic algorithms                            41
#                                           Genetic programming                           12
#                                           Graphical models                              20
#                                           Hidden Markov models                           8
#                                           Inductive logic programming                    5
#                                           Kernel methods for machine learning           15
#                                           Language modeling                             11
#                                           Latent variable models                        25
#                                           Learning in computer vision                    4
#                                           Log-linear models                              2
#                                           Loss functions                                 8
#                                           Machine learning algorithms                   57
#                                           Machine learning researchers                  82
#                                           Machine learning task                          5
#                                           Markov models                                 52
#                                           Markov networks                                7
#                                           Nature-inspired metaheuristics                18
#                                           Neural network software                       22
#                                           Semisupervised learning                        1
#                                           Social network analysis software               6
#                                           Statistical natural language processing       35
#                                           Structural equation models                     9
#                                           Structured prediction                          4
#                                           Supervised learning                            1
#                                           Support vector machines                        8
#                                           Unsupervised learning                         11
#                                           machine learning                             197
#
# [130 rows x 1 columns]

# %%
print( ml_unique_pages_df.shape)
ml_unique_pages_df.head()
# Out:
# (1095, 4)
#            category    pageid       subcategory  \
# 0  machine learning  43385931  machine learning
# 1  machine learning  49082762  machine learning
# 2  machine learning    233488  machine learning
# 3  machine learning  53587467  machine learning
# 4  machine learning   3771060  machine learning
#
#                                             title
# 0                                Data exploration
# 1  List of datasets for machine learning research
# 2                                Machine learning
# 3                     Outline of machine learning
# 4                                Accuracy paradox

# %%
ml_unique_pages_df.pageid.apply()
# Out:
#               category    pageid              subcategory  \
# 0     machine learning  43385931         machine learning
# 1     machine learning  49082762         machine learning
# 2     machine learning    233488         machine learning
# 3     machine learning  53587467         machine learning
# 4     machine learning   3771060         machine learning
# 5     machine learning  43808044         machine learning
# 6     machine learning  28801798         machine learning
# 7     machine learning  45049676         machine learning
# 8     machine learning  52642349         machine learning
# 9     machine learning  30511763         machine learning
# 10    machine learning  50773876         machine learning
# 11    machine learning  20890511         machine learning
# 12    machine learning  49242352         machine learning
# 13    machine learning  19463198         machine learning
# 14    machine learning  14003441         machine learning
# 15    machine learning  31877832         machine learning
# 16    machine learning   9732182         machine learning
# 17    machine learning  35867897         machine learning
# 18    machine learning  40973765         machine learning
# 19    machine learning  50211107         machine learning
# 20    machine learning  40678189         machine learning
# 21    machine learning  55075082         machine learning
# 22    machine learning    205393         machine learning
# 23    machine learning  50646178         machine learning
# 24    machine learning   1191936         machine learning
# 25    machine learning  44439173         machine learning
# 26    machine learning  53631046         machine learning
# 27    machine learning  39182554         machine learning
# 28    machine learning   8964665         machine learning
# 29    machine learning  17114678         machine learning
# ...                ...       ...                      ...
# 1066  machine learning   9649605         Causal inference
# 1067  machine learning     59861         Causal inference
# 1068  machine learning   1900609         Causal inference
# 1069  machine learning   1305037         Causal inference
# 1070  machine learning   5990317         Causal inference
# 1071  machine learning    393736         Causal inference
# 1072  machine learning   1562189         Causal inference
# 1073  machine learning  45418224         Causal inference
# 1074  machine learning  25091359         Causal inference
# 1075  machine learning  28168154         Causal inference
# 1076  machine learning  14474114         Causal inference
# 1077  machine learning  16722927         Causal inference
# 1078  machine learning  18134289         Causal inference
# 1079  machine learning   2940730         Causal inference
# 1080  machine learning    163180         Causal inference
# 1081  machine learning   5700418         Causal inference
# 1082  machine learning    394392         Causal inference
# 1083  machine learning     46096         Causal inference
# 1084  machine learning  21963702          Markov networks
# 1085  machine learning  22931116          Markov networks
# 1086  machine learning   3670357          Markov networks
# 1087  machine learning  44132510          Markov networks
# 1088  machine learning  17707632  Support vector machines
# 1089  machine learning  34060917  Support vector machines
# 1090  machine learning  35857112  Support vector machines
# 1091  machine learning  20154492  Support vector machines
# 1092  machine learning  39177819    Unsupervised learning
# 1093  machine learning  50073184    Unsupervised learning
# 1094  machine learning    404084    Unsupervised learning
# 1095  machine learning     47805    Unsupervised learning
#
#                                                   title
# 0                                      Data exploration
# 1        List of datasets for machine learning research
# 2                                      Machine learning
# 3                           Outline of machine learning
# 4                                      Accuracy paradox
# 5                                 Action model learning
# 6                    Active learning (machine learning)
# 7                          Adversarial machine learning
# 8                                                  AIVA
# 9                                                  AIXI
# 10                                  Algorithm Selection
# 11                                Algorithmic inference
# 12                                              AlphaGo
# 13                              Apprenticeship learning
# 14                                   Bag-of-words model
# 15                                            Ball tree
# 16                                            Base rate
# 17     Bayesian interpretation of kernel regularization
# 18                                Bayesian optimization
# 19                      Bayesian structural time series
# 20                               Bias–variance tradeoff
# 21                                                BigDL
# 22                                Binary classification
# 23                                        Bing Predicts
# 24                                      Bongard problem
# 25                                  Bradley–Terry model
# 26                                     Caffe (software)
# 27                            Catastrophic interference
# 28                                     Category utility
# 29                                           CBCL (MIT)
# ...                                                 ...
# 1066                                  Event correlation
# 1067                                         Experiment
# 1068                                  External validity
# 1069                                   Field experiment
# 1070                                       Ignorability
# 1071                                Inductive reasoning
# 1072                                  Internal validity
# 1073                Mathematics and plausible reasoning
# 1074                               Oaxaca decomposition
# 1075                           Principal stratification
# 1076                            Probabilistic causation
# 1077                          Propensity score matching
# 1078                   Qualitative comparative analysis
# 1079                                  Random assignment
# 1080                        Randomized controlled trial
# 1081                                 Rubin causal model
# 1082                                     Selection bias
# 1083                                  Simpson's paradox
# 1084                        Hammersley–Clifford theorem
# 1085                         Hidden Markov random field
# 1086                               Markov logic network
# 1087                           Probabilistic soft logic
# 1088                          Margin (machine learning)
# 1089                                        Ranking SVM
# 1090  Regularization perspectives on support vector ...
# 1091                    Sequential minimal optimization
# 1092                                 Cognitive computer
# 1093                    Generative adversarial networks
# 1094                                     Hebbian theory
# 1095                                Vector quantization
#
# [1096 rows x 4 columns]

# %%
t_sample = ml_unique_pages_df.loc[0, :]
t_sample.apply()

# %%
t_sample.pageid.apply( grab_content, args)
# Out:
# 43385931

# %%
ml_unique_pages_df.loc[0,'article'] =

# %%
ml_unique_pages_df.loc[0:5,'article'] = ml_unique_pages_df.loc[0:5, :].pageid.apply( rc.grab_content, clean = False )  ## Don't clean it yet

# %%
sample_df = ml_unique_pages_df.head(5).copy()

# %%
pids = sample_df.pageid.tolist()
pids
# Out:
# [43385931, 49082762, 233488, 53587467, 3771060]

# %%
ml_unique_pages_df.loc[0:5,'article']

# %%
test_art = ml_unique_pages_df.loc[3,'article']

# %%
test_art
# Out:
# 'The following outline is provided as an overview of and topical guide to machine learning:\nMachine learning – subfield of computer science (more particularly soft computing) that evolved from the study of pattern recognition and computational learning theory in artificial intelligence. In 1959, Arthur Samuel defined machine learning as a "Field of study that gives computers the ability to learn without being explicitly programmed". Machine learning explores the study and construction of algorithms that can learn from and make predictions on data. Such algorithms operate by building a model from an example training set of input observations in order to make data-driven predictions or decisions expressed as outputs, rather than following strictly static program instructions.\n\n\n== What type of thing is machine learning? ==\nAn academic discipline\nA branch of science\nAn applied science\nA subfield of computer science\nA branch of artificial intelligence\nA subfield of soft computing\n\n\n== Branches of machine learning ==\n\n\n=== Subfields ===\nComputational learning theory – studying the design and analysis of machine learning algorithms.\nGrammar induction\nMeta learning\n\n\n=== Cross-disciplinary fields ===\nAdversarial machine learning\nPredictive analytics\nQuantum machine learning\nRobot learning\n\n\n== Machine learning hardware ==\nGraphics processing unit\nTensor processing unit\nVision processing unit\n\n\n== Machine learning tools ==\nComparison of deep learning software\nComparison of deep learning software/Resources\n\n\n=== Proprietary frameworks ===\nAmazon Machine Learning\nAzure ML Studio\nDistBelief – replaced by TensorFlow\nMicrosoft Cognitive Toolkit\n\n\n=== Open source frameworks ===\nApache Singa\nCaffe\nH2O\nMLPACK\nTensorFlow\nTorch\n\n\n=== Machine learning libraries ===\nDeeplearning4j\nTheano\nScikit-learn\n\n\n== Machine learning methods ==\nDimensionality reduction\nCCA\nFactor analysis\nIndependent component analysis (ICA)\nLinear discriminant analysis (LDA)\nMultidimensional scaling (MDS)\nNon-negative matrix factorization (NMF)\nPartial least squares regression (PLSR)\nPrincipal component analysis (PCA)\nPrincipal component regression (PCR)\nProjection pursuit\nSammon mapping\nt-distributed stochastic neighbor embedding (t-SNE)\n\nEnsemble learning\nBoosting\nBootstrap aggregating (Bagging)\nAdaBoost\nStacked Generalization (blending)\nGradient boosting machine (GBM)\nGradient boosted decision tree (GBRT)\nRandom Forest\n\nInstance-based algorithm\nK-nearest neighbors algorithm (KNN)\nLearning vector quantization (LVQ)\nSelf-organizing map (SOM)\n\nRegression analysis\nLogistic regression\nOrdinary least squares regression (OLSR)\nLinear regression\nStepwise regression\nMultivariate adaptive regression splines (MARS)\n\nRegularization algorithm\nRidge regression\nLeast Absolute Shrinkage and Selection Operator (LASSO)\nElastic net\nLeast-angle regression (LARS)\n\nClassifiers\nProbabilistic classifier\nNaive Bayes classifier\n\nBinary classifier\nLinear classifier\nHierarchical classifier\n\n\n=== Supervised learning ===\nSupervised learning\nAODE\nAssociation rule learning algorithms\nApriori algorithm\nEclat algorithm\n\nCase-based reasoning\nGaussian process regression\nGene expression programming\nGroup method of data handling (GMDH)\nInductive logic programming\nInstance-based learning\nLazy learning\nLearning Automata\nLearning Vector Quantization\nLogistic Model Tree\nMinimum message length (decision trees, decision graphs, etc.)\nNearest Neighbor Algorithm\nAnalogical modeling\n\nProbably approximately correct learning (PAC) learning\nRipple down rules, a knowledge acquisition methodology\nSymbolic machine learning algorithms\nSupport vector machines\nRandom Forests\nEnsembles of classifiers\nBootstrap aggregating (bagging)\nBoosting (meta-algorithm)\n\nOrdinal classification\nInformation fuzzy networks (IFN)\nConditional Random Field\nANOVA\nQuadratic classifiers\nk-nearest neighb ...

# %%
#test_art.decode('unicode_escape').encode('ascii','ignore')
test_art = re.sub('[\n\t]',' ', test_art.lower())
test_art = re.sub('[\<\>\(\)\[\]\{\}\"]','', test_art.lower())
#test_art = re.sub('[=-+]',' ', test_art.lower())

test_art
# Out:
# "the following outline is provided as an overview of and topical guide to machine learning: machine learning – subfield of computer science more particularly soft computing that evolved from the study of pattern recognition and computational learning theory in artificial intelligence. in 1959, arthur samuel defined machine learning as a field of study that gives computers the ability to learn without being explicitly programmed. machine learning explores the study and construction of algorithms that can learn from and make predictions on data. such algorithms operate by building a model from an example training set of input observations in order to make data-driven predictions or decisions expressed as outputs, rather than following strictly static program instructions.   == what type of thing is machine learning? == an academic discipline a branch of science an applied science a subfield of computer science a branch of artificial intelligence a subfield of soft computing   == branches of machine learning ==   === subfields === computational learning theory – studying the design and analysis of machine learning algorithms. grammar induction meta learning   === cross-disciplinary fields === adversarial machine learning predictive analytics quantum machine learning robot learning   == machine learning hardware == graphics processing unit tensor processing unit vision processing unit   == machine learning tools == comparison of deep learning software comparison of deep learning software/resources   === proprietary frameworks === amazon machine learning azure ml studio distbelief – replaced by tensorflow microsoft cognitive toolkit   === open source frameworks === apache singa caffe h2o mlpack tensorflow torch   === machine learning libraries === deeplearning4j theano scikit-learn   == machine learning methods == dimensionality reduction cca factor analysis independent component analysis ica linear discriminant analysis lda multidimensional scaling mds non-negative matrix factorization nmf partial least squares regression plsr principal component analysis pca principal component regression pcr projection pursuit sammon mapping t-distributed stochastic neighbor embedding t-sne  ensemble learning boosting bootstrap aggregating bagging adaboost stacked generalization blending gradient boosting machine gbm gradient boosted decision tree gbrt random forest  instance-based algorithm k-nearest neighbors algorithm knn learning vector quantization lvq self-organizing map som  regression analysis logistic regression ordinary least squares regression olsr linear regression stepwise regression multivariate adaptive regression splines mars  regularization algorithm ridge regression least absolute shrinkage and selection operator lasso elastic net least-angle regression lars  classifiers probabilistic classifier naive bayes classifier  binary classifier linear classifier hierarchical classifier   === supervised learning === supervised learning aode association rule learning algorithms apriori algorithm eclat algorithm  case-based reasoning gaussian process regression gene expression programming group method of data handling gmdh inductive logic programming instance-based learning lazy learning learning automata learning vector quantization logistic model tree minimum message length decision trees, decision graphs, etc. nearest neighbor algorithm analogical modeling  probably approximately correct learning pac learning ripple down rules, a knowledge acquisition methodology symbolic machine learning algorithms support vector machines random forests ensembles of classifiers bootstrap aggregating bagging boosting meta-algorithm  ordinal classification information fuzzy networks ifn conditional random field anova quadratic classifiers k-nearest neighbor boosting sprint  bayesian networks naive bayes  hidden markov models   ==== artificial neural network ==== artificial neural network autoencoder backpropagation boltzmann machine convolutional neural ...

# %%
get_article = lambda x: unique_pages_df[ unique_pages_df.pageid == x].article.tolist()[0]
category_pages_df.pageid.apply( get_article)

#category_pages_df.loc[:, 'article'] =

# %%
retrieve_article = lambda x: ml_unique_pages_df[ ml_unique_pages_df.pageid == x].article.tolist()[0]

# %%
row = ml_unique_pages_df[ ml_unique_pages_df.pageid == 43385931]

# %%
row.title.tolist()
# Out:
# ['Data exploration']

# %%
## Union of pages in category includes 1 of each article
sum( ml_unique_pages_df.title.value_counts() > 1)
# Out:
# 0

# %%
len(ml_category_pages_df.category.unique().tolist())
# Out:
# 48

# %%
ml_category_pages_df.drop( ['pageid'], axis = 1).groupby( by = ['category', 'subcategory']).count()
# Out:
#                                                                                      title
# category                                  subcategory
# Applied machine learning                  Applied machine learning                      35
# Artificial immune systems                 Artificial immune systems                      4
# Artificial intelligence conferences       Artificial intelligence conferences           14
# Artificial neural networks                Artificial neural networks                   129
#                                           Deep learning                                 20
#                                           Neural network software                       22
# Bayesian networks                         Bayesian networks                             12
# Causal inference                          Causal inference                              24
# Classification algorithms                 Artificial neural networks                   129
#                                           Classification algorithms                     81
#                                           Decision trees                                17
#                                           Deep learning                                 20
#                                           Ensemble learning                             14
#                                           Neural network software                       22
# Cluster analysis                          Cluster analysis                              18
#                                           Cluster analysis algorithms                   38
#                                           Clustering criteria                           16
# Cluster analysis algorithms               Cluster analysis algorithms                   38
# Clustering criteria                       Clustering criteria                           16
# Computational learning theory             Computational learning theory                 21
# Data mining and machine learning software Data mining and machine learning software     87
#                                           Social network analysis software               6
# Datasets in computer vision               Datasets in computer vision                   10
# Datasets in machine learning              Datasets in computer vision                   10
#                                           Datasets in machine learning                   6
# Decision trees                            Decision trees                                17
# Deep learning                             Deep learning                                 20
# Dimension reduction                       Dimension reduction                           39
#                                           Factor analysis                               19
# Ensemble learning                         Ensemble learning                             14
# ...                                                                                    ...
# machine learning                          Evolutionary algorithms                       40
#                                           Factor analysis                               19
#                                           Gene expression programming                    1
#                                           Genetic algorithms                            41
#                                           Genetic programming                           12
#                                           Graphical models                              20
#                                           Hidden Markov models                           8
#                                           Inductive logic programming                    5
#                                           Kernel methods for machine learning           15
#                                           Language modeling                             11
#                                           Latent variable models                        25
#                                           Learning in computer vision                    4
#                                           Log-linear models                              2
#                                           Loss functions                                 8
#                                           Machine learning algorithms                   57
#                                           Machine learning researchers                  82
#                                           Machine learning task                          5
#                                           Markov models                                 52
#                                           Markov networks                                7
#                                           Nature-inspired metaheuristics                18
#                                           Neural network software                       22
#                                           Semisupervised learning                        1
#                                           Social network analysis software               6
#                                           Statistical natural language processing       35
#                                           Structural equation models                     9
#                                           Structured prediction                          4
#                                           Supervised learning                            1
#                                           Support vector machines                        8
#                                           Unsupervised learning                         11
#                                           machine learning                             197
#
# [130 rows x 1 columns]

# %%
categories_df = ml_category_pages_df.drop_duplicates( subset = ['category']).reset_index( drop=True).copy()
print
categories_df[['category']].head()

#categories_df = pd.DataFrame({'category':ml_category_pages_df.subcategory.unique() }) 
#categories_df.head()
# Out:
#                      category
# 0            machine learning
# 1    Applied machine learning
# 2   Classification algorithms
# 3  Artificial neural networks
# 4               Deep learning

# %%
sub_categories_df = ml_category_pages_df.drop(['pageid','title'], axis = 1).drop_duplicates( subset = ['category', 'subcategory']).reset_index( drop=True).copy()
print( sub_categories_df.shape)
sub_categories_df.head()
# Out:
# (130, 2)
#            category                 subcategory
# 0  machine learning            machine learning
# 1  machine learning    Applied machine learning
# 2  machine learning   Classification algorithms
# 3  machine learning  Artificial neural networks
# 4  machine learning               Deep learning

# %%
import request_cat as rc
import database as db
import pandas as pd
from datetime import datetime

# %%
def download( *category, depth, pickle = False):
    
    categories = list(*category)
    
    for cat in categories:
        start = datetime.now()
        if pickle:
            pages_df = pd.read_pickle('./docker/postgres/data/{}'.format( pickle) )
        else:
            category_pages_df, unique_pages_df = rc.fill_unique_pages(cat, depth = depth, grab = True)   ## REMOVE rc.
        n_pages = unique_pages_df.shape[0]
        print( "\t\t\tUpdating pages table:\n\t\t\t\tCollecting text for {} articles".format(n_pages) )
        results = unique_pages_df.apply( lambda x: db.update_page_table( x.pageid, x.title), axis = 1)
        #results = pages_df.apply( lambda x: db.update_page_table( x.pageid, x.title, x.text), axis = 1)
                    ##NOTICE: num_categories = num_sub_categories = union of categories and nested categories
        print( "\t\t\tUpdating categories table")
        categories_df = pd.DataFrame({'category':category_pages_df.subcategory.unique() }) 
        results = categories_df.apply( lambda x: db.update_category_table( x.category), axis = 1)

        print("\t\t\tUpdating subcategories table")
        subcategories_df = category_pages_df.drop_duplicates( subset = ['category', 'subcategory']).copy()
        results = subcategories_df.apply( lambda x: db.update_sub_category_table( x.subcategory, x.category), axis = 1) 
            
        print("\t\t\tUpdating page-category (link) table")
        subcat_page_df = category_pages_df.drop_duplicates( subset = ['subcategory', 'pageid']).copy()
        results = subcat_page_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory), axis = 1)
        
        timeduration = round((datetime.now()-start).seconds/60,2) ## minutes
        
        print("\t\t\tArticle colletion took a total of {} minutes.".format( cat, timeduration) )
        print("_"*75)

# %%
def update_category_table(category):
    query = """BEGIN;
               INSERT INTO categories (category) VALUES ('{}');
               COMMIT;""".format(category )
    #ALTER TABLE category category_id SERIAL PRIMARY KEY;
    query = re.sub( "\s+", " ", query)
    return query_to_dictionary( query, fetch_res = False)
    
def update_sub_category_table(subcategory, category):
    #clean_subcategory = re.sub('[^a-z0-9 ]',' ', subcategory.lower())
    query = """BEGIN;
               INSERT INTO subcategories (subcategory, category_id) 
               VALUES ('{}',(SELECT category_id FROM categories WHERE category = '{}'));
               COMMIT;""".format(subcategory, category )
    #ALTER TABLE category category_id SERIAL PRIMARY KEY;
    query = re.sub("\s+", " ", query)
    return query_to_dictionary( query, fetch_res = False)

### OLD
def update_page_category_table( pageid, subcategory):
    query = """BEGIN;
               INSERT INTO page_category (pageid, subcategory_id) 
               VALUES ({}, (SELECT subcategory_id FROM subcategories WHERE subcategory = '{}'));
               COMMIT;""".format( pageid, subcategory)
    query = re.sub("\s+", " ", query)
    return query_to_dictionary( query, fetch_res = False)

# %%
db.clear_table( 'pages' )
db.clear_table( 'categories' )
db.clear_table( 'subcategories' )
db.clear_table( 'page_category' )

# %%
db.query_to_dataframe('SELECT * FROM pages LIMIT 5;')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
download( ['machine learning', 'business software'], depth = 1)

# %%
set(category_pages_df.category.unique()) == set(category_pages_df.subcategory.unique())
# Out:
# True

# %%
print( "\t\t\tUpdating categories table")

## NOTICE:  set(category_pages_df.category.unique()) == set(category_pages_df.subcategory.unique())
## Update categories table
categories_df = pd.DataFrame({'category':category_pages_df.subcategory.unique() }) 
results = categories_df.apply( lambda x: db.update_category_table( x.category), axis = 1)
#db.update_category_table( cat)

print("\t\t\tUpdating subcategories table")

subcategories_df = category_pages_df.drop_duplicates( subset = ['category', 'subcategory']).copy()
results = subcategories_df.apply( lambda x: db.update_sub_category_table( x.subcategory, x.category), axis = 1) 
#results = subcategories_df.apply( lambda x: db.update_sub_category_table( x.subcategory, cat), axis = 1) 

print("\t\t\tUpdating page-category (link) table")


results = category_pages_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory), axis = 1)

timeduration = round((datetime.now()-start).seconds/60,2) ## minutes

print("\t\t\tArticle colletion took a total of {} minutes.".format( cat, timeduration) )
print("_"*75)
# Out:
# 			Updating categories table
# 			Updating subcategories table
# 			Updating page-category (link) table
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-45-7addbb0767c7> in <module>()
#      16
#      17
# ---> 18 results = category_pages_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory), axis = 1)
#      19
#      20 timeduration = round((datetime.now()-start).seconds/60,2) ## minutes
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-45-7addbb0767c7> in <lambda>(x)
#      16
#      17
# ---> 18 results = category_pages_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory), axis = 1)
#      19
#      20 timeduration = round((datetime.now()-start).seconds/60,2) ## minutes
#
# ~/database.py in update_page_category_table(pageid, subcategory)
#      72                COMMIT;""".format( pageid, subcategory)
#      73     query = re.sub("\s+", " ", query)
# ---> 74     return query_to_dictionary( query, fetch_res = False)
#      75
#      76 def category_query( *category, df = False):
#
# ~/database.py in query_to_dictionary(query, fetch_res)
#      14 def query_to_dictionary(query, fetch_res=True):
#      15     con, cur = connect_to_db()
# ---> 16     cur.execute(query)
#      17     if fetch_res:
#      18         results = cur.fetchall()
#
# /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py in execute(self, query, vars)
#     247         self.column_mapping = []
#     248         self._query_executed = 1
# --> 249         return super(RealDictCursor, self).execute(query, vars)
#     250
#     251     def callproc(self, procname, vars=None):
#
# ProgrammingError: ('more than one row returned by a subquery used as an expression\n', 'occurred at index 0')

# %%
import re
#db.clear_table( 'page_category' )
inner_query = '''SELECT stuff.category, stuff.subcategory, pc.pageid 
    FROM (SELECT category, subcategory, subcategory_id 
           FROM subcategories sc 
           JOIN categories c 
           ON sc.category_id = c.category_id ) as stuff 
    JOIN page_category pc 
    ON stuff.subcategory_id = pc.subcategory_id'''

query = '''SELECT crap.category, crap.subcategory, p.title, crap.pageid  
           FROM ({}) as crap
           JOIN pages p
           ON crap.pageid = p.pageid;'''.format( inner_query)
query = re.sub( '\s+',' ', query)
query


db.query_to_dataframe( query) #  'Select * from page_category;'
# Out:
#              category    pageid       subcategory  \
# 0    machine learning  43385931  machine learning
# 1    machine learning  43385931  machine learning
# 2    machine learning  49082762  machine learning
# 3    machine learning  49082762  machine learning
# 4    machine learning    233488  machine learning
# 5    machine learning    233488  machine learning
# 6    machine learning  53587467  machine learning
# 7    machine learning  53587467  machine learning
# 8    machine learning   3771060  machine learning
# 9    machine learning   3771060  machine learning
# 10   machine learning  43808044  machine learning
# 11   machine learning  43808044  machine learning
# 12   machine learning  28801798  machine learning
# 13   machine learning  28801798  machine learning
# 14   machine learning  45049676  machine learning
# 15   machine learning  45049676  machine learning
# 16   machine learning  52642349  machine learning
# 17   machine learning  52642349  machine learning
# 18   machine learning  30511763  machine learning
# 19   machine learning  30511763  machine learning
# 20   machine learning  50773876  machine learning
# 21   machine learning  50773876  machine learning
# 22   machine learning  20890511  machine learning
# 23   machine learning  20890511  machine learning
# 24   machine learning  49242352  machine learning
# 25   machine learning  49242352  machine learning
# 26   machine learning  19463198  machine learning
# 27   machine learning  19463198  machine learning
# 28   machine learning  14003441  machine learning
# 29   machine learning  14003441  machine learning
# ..                ...       ...               ...
# 364  machine learning   1514392  machine learning
# 365  machine learning   1514392  machine learning
# 366  machine learning  50828755  machine learning
# 367  machine learning  50828755  machine learning
# 368  machine learning    960361  machine learning
# 369  machine learning    960361  machine learning
# 370  machine learning   3920550  machine learning
# 371  machine learning   3920550  machine learning
# 372  machine learning  47577902  machine learning
# 373  machine learning  47577902  machine learning
# 374  machine learning   5077439  machine learning
# 375  machine learning   5077439  machine learning
# 376  machine learning  19058043  machine learning
# 377  machine learning  19058043  machine learning
# 378  machine learning  22999791  machine learning
# 379  machine learning  22999791  machine learning
# 380  machine learning    233497  machine learning
# 381  machine learning    233497  machine learning
# 382  machine learning  47228422  machine learning
# 383  machine learning  47228422  machine learning
# 384  machine learning  39945557  machine learning
# 385  machine learning  39945557  machine learning
# 386  machine learning  43502368  machine learning
# 387  machine learning  43502368  machine learning
# 388  machine learning   7578809  machine learning
# 389  machine learning   7578809  machine learning
# 390  machine learning  52992310  machine learning
# 391  machine learning  52992310  machine learning
# 392  machine learning  47527969  machine learning
# 393  machine learning  47527969  machine learning
#
#                                               title
# 0                                  data exploration
# 1                                  data exploration
# 2    list of datasets for machine learning research
# 3    list of datasets for machine learning research
# 4                                  machine learning
# 5                                  machine learning
# 6                       outline of machine learning
# 7                       outline of machine learning
# 8                                  accuracy paradox
# 9                                  accuracy paradox
# 10                            action model learning
# 11                            action model learning
# 12                 active learning machine learning
# 13                 active learning machine learning
# 14                     adversarial machine learning
# 15                     adversarial machine learning
# 16                                             aiva
# 17                                             aiva
# 18                                             aixi
# 19                                             aixi
# 20                              algorithm selection
# 21                              algorithm selection
# 22                            algorithmic inference
# 23                            algorithmic inference
# 24                                          alphago
# 25                                          alphago
# 26                          apprenticeship learning
# 27                          apprenticeship learning
# 28                                 bagofwords model
# 29                                 bagofwords model
# ..                                              ...
# 364                                        test set
# 365                                        test set
# 366                    timeline of machine learning
# 367                    timeline of machine learning
# 368                   transduction machine learning
# 369                   transduction machine learning
# 370                               transfer learning
# 371                               transfer learning
# 372                          trax image recognition
# 373                          trax image recognition
# 374                           ugly duckling theorem
# 375                           ugly duckling theorem
# 376                                  uncertain data
# 377                                  uncertain data
# 378              uniform convergence in probability
# 379              uniform convergence in probability
# 380                           unsupervised learning
# 381                           unsupervised learning
# 382                         user behavior analytics
# 383                         user behavior analytics
# 384                                  validation set
# 385                                  validation set
# 386                      vanishing gradient problem
# 387                      vanishing gradient problem
# 388                          version space learning
# 389                          version space learning
# 390                             vgg image annotator
# 391                             vgg image annotator
# 392                                        word2vec
# 393                                        word2vec
#
# [394 rows x 4 columns]

# %%
## Original
def update_page_category_table( pageid, subcategory):
    query = """BEGIN;
               INSERT INTO page_category (pageid, subcategory_id) 
               VALUES ({}, (SELECT subcategory_id FROM subcategories WHERE subcategory = '{}'));
               COMMIT;""".format( pageid, subcategory)
    query = re.sub("\s+", " ", query)
    return db.query_to_dictionary( query, fetch_res = False)

# %%
## New
def update_page_category_table( pageid, subcategory, category, display = False):
    query_for_category_id = """SELECT category_id
                            FROM categories
                            WHERE category = '{}'""".format( category)

    query_for_subcategory_id = """SELECT subcategory_id 
                              FROM subcategories
                              WHERE subcategory = '{}'
                              AND category_id = ({})""".format( subcategory, query_for_category_id)
    
    query = """BEGIN;
               INSERT INTO page_category (pageid, subcategory_id) 
               VALUES ({}, ({}));
               COMMIT;""".format( pageid, query_for_subcategory_id)
    ## VALUES ({}, (SELECT subcategory_id FROM subcategories WHERE subcategory = '{}'));
    query = re.sub("\s+", " ", query)
    if display:
        return query
    else:
        return db.query_to_dictionary( query, fetch_res = True)

# %%
##  machine learning	Applied machine learning	179
## machine learning Applied machine learning 15795950 Activity recognition
update_page_category_table( 15795950, 'Applied machine learning', 'machine learning', display = True)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-105-6c09491813f6> in <module>()
#       1 ##  machine learning    Applied machine learning        179
#       2 ## machine learning Applied machine learning 15795950 Activity recognition
# ----> 3 update_page_category_table( 15795950, 'Applied machine learning', 'machine learning', display = False)
#
# <ipython-input-104-02e17a1e6fad> in update_page_category_table(pageid, subcategory, category, display)
#      20         return query
#      21     else:
# ---> 22         return db.query_to_dictionary( query, fetch_res = True)
#
# ~/database.py in query_to_dictionary(query, fetch_res)
#      16     cur.execute(query)
#      17     if fetch_res:
# ---> 18         results = cur.fetchall()
#      19     else:
#      20         results = None
#
# /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py in fetchall(self)
#     103             self._build_index()
#     104         if not self._prefetch:
# --> 105             res = super(DictCursorBase, self).fetchall()
#     106         return res
#     107
#
# ProgrammingError: no results to fetch

# %%
db.query_to_dictionary(fetch_res=False)

# %%
db.query_to_dataframe("SELECT c.category, subcategory, subcategory_id FROM subcategories sc JOIN categories c ON sc.category_id = c.category_id WHERE subcategory = '{}'".format('Applied machine learning' ))
# Out:
#                    category               subcategory  subcategory_id
# 0          machine learning  Applied machine learning             179
# 1  Applied machine learning  Applied machine learning             226

# %%
## Next one to add
## Applied machine learning 15795950 Activity recognition

# %%
query_for_category_id_ = '''SELECT category_id
                            FROM categories
                            WHERE category = {}'''.format( category)

query_for_subcategory_id = """SELECT subcategory_id 
                              FROM subcategories
                              WHERE subcategory = '{}'
                              AND category_id = {}""".format( subcategory, query_for_category_id)
query_for_subcategory_id = re.sub("\s+", " ", query_for_subcategory_id)

# %%
Applied machine learning 15795950 Activity recognition
Applied machine learning 41916168 AlchemyAPI
Applied machine learning 55075082 BigDL
Applied machine learning 53631046 Caffe (software)

# %%
update_page_category_table( 15795950, 'Applied machine learning' )
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-76-6ebc28b24264> in <module>()
# ----> 1 update_page_category_table( 15795950, 'Applied machine learning' )
#
# <ipython-input-75-01f445ae3238> in update_page_category_table(pageid, subcategory)
#       5                COMMIT;""".format( pageid, subcategory)
#       6     query = re.sub("\s+", " ", query)
# ----> 7     return db.query_to_dictionary( query, fetch_res = False)
#
# ~/database.py in query_to_dictionary(query, fetch_res)
#      14 def query_to_dictionary(query, fetch_res=True):
#      15     con, cur = connect_to_db()
# ---> 16     cur.execute(query)
#      17     if fetch_res:
#      18         results = cur.fetchall()
#
# /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py in execute(self, query, vars)
#     247         self.column_mapping = []
#     248         self._query_executed = 1
# --> 249         return super(RealDictCursor, self).execute(query, vars)
#     250
#     251     def callproc(self, procname, vars=None):
#
# ProgrammingError: more than one row returned by a subquery used as an expression

# %%
print("\t\t\tUpdating page-category (link) table")
subcat_page_df = category_pages_df.drop_duplicates( subset = ['subcategory', 'pageid']).copy()
results = subcat_page_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory), axis = 1)

# %%
db.clear_table( 'page_category' )

# %%
db.query_to_dataframe('SELECT * FROM page_category;')
# Out:
#    category_page_id    pageid  subcategory_id
# 0              6316  43385931             178
# 1              6317  43385931             178
# 2              6318  15795950             179

# %%
import database as db

# %%
# pageid, subcategory, category):
print("\t\t\tUpdating page-category (link) table")
subcat_page_df = ml_category_pages_df.drop_duplicates( subset = ['subcategory', 'pageid']).copy()
results = subcat_page_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory, x.category), axis = 1)
# Out:
# 			Updating page-category (link) table
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-62a60b4b4901> in <module>()
#       3 print("\t\t\tUpdating page-category (link) table")
#       4 subcat_page_df = ml_category_pages_df.drop_duplicates( subset = ['subcategory', 'pageid']).copy()
# ----> 5 results = subcat_page_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory, x.category), axis = 1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-99-62a60b4b4901> in <lambda>(x)
#       3 print("\t\t\tUpdating page-category (link) table")
#       4 subcat_page_df = ml_category_pages_df.drop_duplicates( subset = ['subcategory', 'pageid']).copy()
# ----> 5 results = subcat_page_df.apply( lambda x: db.update_page_category_table( x.pageid, x.subcategory, x.category), axis = 1)
#
# TypeError: ('update_page_category_table() takes 2 positional arguments but 3 were given', 'occurred at index 0')
